# %%
import random

# %%
def _noise(value: float, pct: float = 0.04) -> float:
    return value * (1 + random.uniform(-pct, pct))

# %%
value = 100
_noise(value)
# Out:
# 101.0908612506603

# %%
(1 + random.uniform(-0.04, 0.04))
# Out:
# 0.9947082327280214
